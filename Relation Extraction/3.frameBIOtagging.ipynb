# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonkim313/dataCampusProject-Team10/blob/master/2.frameBIOtagging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Thu Jul 30 13:54:23 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   63C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 778kB 4.6MB/s
# ...
#      |████████████████████████████████| 1.1MB 13.4MB/s
# ...
#      |████████████████████████████████| 890kB 30.7MB/s
# ...
#      |████████████████████████████████| 3.0MB 57.7MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=243eb8323193b57a0a0c00c9ac7913f5970234b75619b9c991670b3d46f9efe8
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
# !apt-get update
# !apt-get install g++ openjdk-8-jdk 
# !pip3 install konlpy
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Get:9 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# ...

# %%
# %cd /content/drive/Shared drives/BigDATA TEAM 10/OpenInformationExtraction
# Out:
# /content/drive/Shared drives/BigDATA TEAM 10/OpenInformationExtraction

# %%
# !pwd
# Out:
# /content/drive/Shared drives/BigDATA TEAM 10/OpenInformationExtraction

# %%
from frameBERT import frame_parser
import pprint
path="/content/drive/Shared drives/BigDATA TEAM 10/OpenInformationExtraction"
parser = frame_parser.FrameParser(model_path=path, language='ko')
# Out:
# srl model: framenet
# language: ko
# version: 1.2
# using viterbi: False
# using masking: True
# pretrained BERT: bert-base-multilingual-cased
# using TGT special token: True
# used dictionary:
# 	 /content/drive/Shared drives/BigDATA TEAM 10/OpenInformationExtraction/frameBERT/src/../koreanframenet/resource/info/kfn1.2_lu2idx.json
# 	 /content/drive/Shared drives/BigDATA TEAM 10/OpenInformationExtraction/frameBERT/src/../koreanframenet/resource/info/kfn1.2_lufrmap.json
# 	 /content/drive/Shared drives/BigDATA TEAM 10/OpenInformationExtraction/frameBERT/src/../koreanframenet/resource/info/mul_bio_frargmap.json
# ...loaded model path: /content/drive/Shared drives/BigDATA TEAM 10/OpenInformationExtraction
# /content/drive/Shared drives/BigDATA TEAM 10/OpenInformationExtraction
# ...model is loaded

# %%
text = '보고서가 말하는 한국 기후변화의 실태는 심각하고 전망은 암담하다.'
parsed = parser.parser(text, sent_id='1', result_format='graph')
list(parsed)
# Out:
# /content/drive/Shared drives/BigDATA TEAM 10/OpenInformationExtraction/frameBERT/src/utils.py:279: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred_logits = sm(masked_logit).view(1,-1)
# [('frame#1-0:Text', 'lu', '보고서가'),
#  ('frame#1-1:Telling', 'lu', '말하는'),
#  ('frame#1-1:Telling', 'fe:Speaker', '보고서'),
#  ('frame#1-1:Telling', 'fe:Message', '한국 기후변화의 실태'),
#  ('frame#1-2:Weather', 'lu', '기후변화의'),
#  ('frame#1-2:Weather', 'fe:Place', '한국'),
#  ('frame#1-3:State_of_entity', 'lu', '실태는'),
#  ('frame#1-3:State_of_entity', 'fe:Entity', '보고서가 말하는'),
#  ('frame#1-3:State_of_entity', 'fe:Entity', '한국 기후변화'),
#  ('frame#1-3:State_of_entity', 'fe:State', '실태')]

# %% [markdown]
# ```
# result_format = ['all','conll','graph','textae']
# ```
#
# 넷중에 하나로 사용 가능

# %%
ex = "국민 여러분의 위대한 선택에 머리 숙여 깊이 감사드립니다. 제 가슴은 한번도 경험하지 못한 나라를 만들겠다는 열정으로 뜨겁습니다. 우리는 새로운 대한민국을 함께 이끌 동반자입니다. 이제 치열한 경쟁의 순간을 뒤로 하고 함께 손을 맞잡고 함께 전진해야 합니다. 존경하는 국민 여러분, 우리는 유례없는 정치적 격변기를 경험했습니다. 전국 각지에서 올바른 선택으로 새로운 대통령을 뽑았습니다. 오늘부터 저는 국민 모두의 대통령이 되겠습니다. 한편 사드 문제 해결을 위해 미국 및 중국과 진지하게 대화하겠습니다. 튼튼한 안보는 막강한 국방력에서 비롯됩니다. 잘못한 일은 잘못했다고 말씀드리겠습니다. 거짓으로 불리한 여론을 덮지 않겠습니다. 광화문 시대 대통령이 되어 국민과 가까운 곳에 있겠습니다."

frames = {}
sentences = ex.split('. ')
for sent in sentences:
  parsed = parser.parser(sent, sent_id='1', result_format='graph')
  frames[sent]=parsed
pprint.pprint(frames)
# Out:
# /content/drive/Shared drives/BigDATA TEAM 10/OpenInformationExtraction/frameBERT/src/utils.py:279: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred_logits = sm(masked_logit).view(1,-1)
# {'거짓으로 불리한 여론을 덮지 않겠습니다': [('frame#1-0:Prevarication', 'lu', '거짓으로'),
#                            ('frame#1-1:Opinion', 'lu', '여론을'),
#                            ('frame#1-1:Opinion', 'fe:Opinion', '거짓으로 불리한'),
#                            ('frame#1-2:Hiding_objects', 'lu', '덮지'),
#                            ('frame#1-2:Hiding_objects', 'fe:Manner', '거짓')],
#  '광화문 시대 대통령이 되어 국민과 가까운 곳에 있겠습니다.': [('frame#1-0:Calendric_unit', 'lu', '시대'),
#                                       ('frame#1-0:Calendric_unit',
#                                        'fe:Name',
#                                        '광화문'),
#                                       ('frame#1-1:Leadership', 'lu', '대통령이'),
# ...

# %%
ex = "국민 여러분의 위대한 선택에 머리 숙여 깊이 감사드립니다. 제 가슴은 한번도 경험하지 못한 나라를 만들겠다는 열정으로 뜨겁습니다. 우리는 새로운 대한민국을 함께 이끌 동반자입니다. 이제 치열한 경쟁의 순간을 뒤로 하고 함께 손을 맞잡고 함께 전진해야 합니다. 존경하는 국민 여러분, 우리는 유례없는 정치적 격변기를 경험했습니다. 전국 각지에서 올바른 선택으로 새로운 대통령을 뽑았습니다. 오늘부터 저는 국민 모두의 대통령이 되겠습니다. 한편 사드 문제 해결을 위해 미국 및 중국과 진지하게 대화하겠습니다. 튼튼한 안보는 막강한 국방력에서 비롯됩니다. 잘못한 일은 잘못했다고 말씀드리겠습니다. 거짓으로 불리한 여론을 덮지 않겠습니다. 광화문 시대 대통령이 되어 국민과 가까운 곳에 있겠습니다."
frames = {}
sentences = ex.split('. ')
for sent in sentences:
  parsed = parser.parser(sent, sent_id='1', result_format='conll')
  frames[sent]=parsed
pprint.pprint(frames)
# Out:
# /content/drive/Shared drives/BigDATA TEAM 10/OpenInformationExtraction/frameBERT/src/utils.py:279: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred_logits = sm(masked_logit).view(1,-1)
# {'거짓으로 불리한 여론을 덮지 않겠습니다': [[['거짓으로', '불리한', '여론을', '덮지', '않겠습니다'],
#                             ['거짓.n', '_', '_', '_', '_'],
#                             ['Prevarication', '_', '_', '_', '_'],
#                             ['O', 'O', 'O', 'O', 'O']],
#                            [['거짓으로', '불리한', '여론을', '덮지', '않겠습니다'],
#                             ['_', '_', '여론.n', '_', '_'],
#                             ['_', '_', 'Opinion', '_', '_'],
#                             ['B-Opinion', 'I-Opinion', 'O', 'O', 'O']],
#                            [['거짓으로', '불리한', '여론을', '덮지', '않겠습니다'],
#                             ['_', '_', '_', '덮다.v', '_'],
#                             ['_', '_', '_', 'Hiding_objects', '_'],
# ...

# %%
pprint.pprint(frames['한편 사드 문제 해결을 위해 미국 및 중국과 진지하게 대화하겠습니다'])
# Out:
# [[['한편', '사드', '문제', '해결을', '위해', '미국', '및', '중국과', '진지하게', '대화하겠습니다'],
#   ['한편.n', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#   ['Relative_time', '_', '_', '_', '_', '_', '_', '_', '_', '_'],
#   ['O',
#    'B-Landmark_occasion',
#    'I-Landmark_occasion',
#    'I-Landmark_occasion',
#    'I-Landmark_occasion',
#    'I-Focal_occasion',
#    'I-Focal_occasion',
#    'I-Focal_occasion',
#    'I-Focal_occasion',
#    'I-Focal_occasion']],
#  [['한편', '사드', '문제', '해결을', '위해', '미국', '및', '중국과', '진지하게', '대화하겠습니다'],
#   ['_', '사다.v', '_', '_', '_', '_', '_', '_', '_', '_'],
#   ['_', 'Commerce_buy', '_', '_', '_', '_', '_', '_', '_', '_'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#  [['한편', '사드', '문제', '해결을', '위해', '미국', '및', '중국과', '진지하게', '대화하겠습니다'],
#   ['_', '_', '문제.n', '_', '_', '_', '_', '_', '_', '_'],
#   ['_', '_', 'Point_of_dispute', '_', '_', '_', '_', '_', '_', '_'],
#   ['O', 'B-Question', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
# ...
