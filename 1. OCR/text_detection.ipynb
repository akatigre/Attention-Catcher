# %%
import os
import wget
import pandas as pd
from PIL import Image

# %% [markdown]
# text_detection model download

# %%
# %cd ./saved_models
# os.chdir('./saved_models')
# Out:
# /workspace/dataCampusProject-Team10/dataCampusProject-Team10/ocr/saved_models

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1-VYCTLAlUfgdTDuXZB1CSu1b5Pbtclml' -O text_detection.pth
# wget.download('https://docs.google.com/uc?export=download&id=1-VYCTLAlUfgdTDuXZB1CSu1b5Pbtclml')
# Out:
# --2020-08-29 13:01:15--  https://docs.google.com/uc?export=download&id=1-VYCTLAlUfgdTDuXZB1CSu1b5Pbtclml
# Resolving docs.google.com (docs.google.com)... 172.217.24.142, 2404:6800:4004:806::200e
# Connecting to docs.google.com (docs.google.com)|172.217.24.142|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-50-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/a5d3i13jfq58c9270t3jm93ku8uvqdrd/1598673675000/01666978145944503968/*/1-VYCTLAlUfgdTDuXZB1CSu1b5Pbtclml?e=download [following]
# ...
# --2020-08-29 13:01:19--  https://doc-00-50-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/a5d3i13jfq58c9270t3jm93ku8uvqdrd/1598673675000/01666978145944503968/*/1-VYCTLAlUfgdTDuXZB1CSu1b5Pbtclml?e=download
# Resolving doc-00-50-docs.googleusercontent.com (doc-00-50-docs.googleusercontent.com)... 216.58.220.129, 216.58.220.129, 2404:6800:4004:813::2001, ...
# ...

# %%
# %cd ..
# os.chdir('..')
# Out:
# /workspace/dataCampusProject-Team10/dataCampusProject-Team10/ocr

# %%
# !python ./text_detection/test.py \
--trained_model ./saved_models/text_detection.pth \
--test_folder ./text_detection/test/test2
# Out:
# Loading weights from checkpoint (./saved_models/text_detection.pth)
# elapsed time : 13.156537294387817sest/test2/test2.jpg

# %%
img = Image.open('./text_detection/test/test2/test2.jpg','r')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1240x1754 at 0x7F46DD5139E8>

# %%
res_img = Image.open('./text_detection/result/res_test2.jpg','r')

# %%
res_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1240x1754 at 0x7F46DBE90AC8>

# %%
# %%writefile text_detection.py
import pandas as pd
import os
from PIL import Image
from text_detection.test import *
import wget
os.chdir('./saved_models')
wget.download('https://docs.google.com/uc?export=download&id=1-VYCTLAlUfgdTDuXZB1CSu1b5Pbtclml')
os.chdir('..')
!python ./text_detection/test.py \
--trained_model ./saved_models/text_detection.pth \
--test_folder ./text_detection/test/
# Out:
# Overwriting text_detection.py

# %%
wget.download('https://docs.google.com/uc?export=download&id=1-VYCTLAlUfgdTDuXZB1CSu1b5Pbtclml')
# Out:
# 'text_detection (1).pth'

# %%
os.chdir('./saved_models')

# %%
# !pwd
# Out:
# /workspace/dataCampusProject-Team10/dataCampusProject-Team10/ocr/saved_models

# %%
# !cd /workspace/dataCampusProject-Team10/dataCampusProject-Team10/ocr/text_detection/

# %%
os.chdir('../text_detection')

# %%
# !pwd
# Out:
# /workspace/dataCampusProject-Team10/dataCampusProject-Team10/ocr/text_detection

# %%
import test1.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-3a205f9a7441> in <module>
# ----> 1 import test1.py
#
# /workspace/dataCampusProject-Team10/dataCampusProject-Team10/ocr/text_detection/test1.py in <module>
#      29
#      30 from collections import OrderedDict
# ---> 31 class Ocr_run(arg.trained_model,ars.test_folder):
#      32     def copyStateDict(state_dict):
#      33         if list(state_dict.keys())[0].startswith("module"):
#
# NameError: name 'arg' is not defined

# %%
a = Ocr
